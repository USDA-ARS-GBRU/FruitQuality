# %%
cd "/content/drive/MyDrive/AA Hulse Kemp Lab/Random/FruitQuality"
# Out:
# /content/drive/MyDrive/Work/Hulse Kemp Lab/Random/FruitQuality

# %%
ls
# Out:
#  Images/              pulp_naive_bayes_pdfs.txt   test_UP_run_script.py
# 'Naive Bayes.ipynb'   test_config.json

# %%
# !pip install plantcv matplotlib==3.6

# %%
# !python "test_UP_run_script.py" --image "Images/FTP.6.62.34_Fruit Quality Fruit3_1_2021-12-07-10-19-18.jpg" --result out.txt --outdir .
# Out:
# Traceback (most recent call last):
#   File "test_UP_run_script.py", line 5, in <module>
#     from plantcv import plantcv as pcv
#   File "/usr/local/lib/python3.8/dist-packages/plantcv/plantcv/__init__.py", line 20, in <module>
#     from plantcv.plantcv import transform
#   File "/usr/local/lib/python3.8/dist-packages/plantcv/plantcv/transform/__init__.py", line 15, in <module>
#     from plantcv.plantcv.transform.warp import warp, warp_align
#   File "/usr/local/lib/python3.8/dist-packages/plantcv/plantcv/transform/warp.py", line 10, in <module>
#     from plantcv.plantcv.visualize import overlay_two_imgs
#   File "/usr/local/lib/python3.8/dist-packages/plantcv/plantcv/visualize/__init__.py", line 3, in <module>
#     from plantcv.plantcv.visualize.histogram import histogram
#   File "/usr/local/lib/python3.8/dist-packages/plantcv/plantcv/visualize/histogram.py", line 10, in <module>
#     from plotnine import ggplot, aes, geom_line, labels, scale_color_manual
# ...

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.2.2'

# %%
import numpy as np

# %%
a = np.int32([[2,4],
              [4,10]])
a
# Out:
# array([[ 2,  4],
#        [ 4, 10]], dtype=int32)

# %%
a * np.float32([2,.5])
# Out:
# array([[4., 2.],
#        [8., 5.]])
